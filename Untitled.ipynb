# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
test.head()
# Out:
#    id        date  store  item
# 0   0  2018-01-01      1     1
# 1   1  2018-01-02      1     1
# 2   2  2018-01-03      1     1
# 3   3  2018-01-04      1     1
# 4   4  2018-01-05      1     1

# %%
df.describe()
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 4 columns):
# date     913000 non-null object
# store    913000 non-null int64
# item     913000 non-null int64
# sales    913000 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 24.4+ MB

# %%
test.head()
# Out:
#    id        date  store  item
# 0   0  2018-01-01      1     1
# 1   1  2018-01-02      1     1
# 2   2  2018-01-03      1     1
# 3   3  2018-01-04      1     1
# 4   4  2018-01-05      1     1

# %%
test.describe()
# Out:
#                  id         store         item
# count  45000.000000  45000.000000  45000.00000
# mean   22499.500000      5.500000     25.50000
# std    12990.525394      2.872313     14.43103
# min        0.000000      1.000000      1.00000
# 25%    11249.750000      3.000000     13.00000
# 50%    22499.500000      5.500000     25.50000
# 75%    33749.250000      8.000000     38.00000
# max    44999.000000     10.000000     50.00000

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 4 columns):
# id       45000 non-null int64
# date     45000 non-null object
# store    45000 non-null int64
# item     45000 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 1.2+ MB

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# By Using Datetime module
com=[df,test]
for i in com:
    i['date']=pd.to_datetime(i['date']) 
    i['year']=i['date'].dt.year
    i['month']=i['date'].dt.month
    i['day_of_month']=i['date'].dt.day 
    i['day_of_week']=i['date'].dt.dayofweek 
    i['day_of_year']=i['date'].dt.dayofyear
    i['week_of_year']=i['date'].dt.weekofyear
df.head()
# Out:
#         date  store  item  sales  year  month  day_of_month  day_of_week  \
# 0 2013-01-01      1     1     13  2013      1             1            1
# 1 2013-01-02      1     1     11  2013      1             2            2
# 2 2013-01-03      1     1     14  2013      1             3            3
# 3 2013-01-04      1     1     13  2013      1             4            4
# 4 2013-01-05      1     1     10  2013      1             5            5
#
#    day_of_year  week_of_year
# 0            1             1
# 1            2             1
# 2            3             1
# 3            4             1
# 4            5             1

# %%
plt.hist(np.sqrt(df['sales']))
# Out:
# (array([3.00000e+01, 7.70000e+03, 9.31540e+04, 2.22292e+05, 2.51215e+05,
#         2.03534e+05, 1.02077e+05, 2.94150e+04, 3.51100e+03, 7.20000e+01]),
#  array([ 0.        ,  1.51986842,  3.03973683,  4.55960525,  6.07947366,
#          7.59934208,  9.11921049, 10.63907891, 12.15894732, 13.67881574,
#         15.19868415]),
#  <a list of 10 Patch objects>)

# %%
sns.countplot(x='sales',hue='year',data=df)

# %%
fig,ax=plt.subplots(nrows=3,ncols=2)
fig.set_size_inches(20,18)

sns.barplot(data=df,x='year',y='sales',ax=ax[0,0])
sns.barplot(data=df,x='month',y='sales',ax=ax[0,1])
sns.barplot(data=df,x='day_of_week',y='sales',ax=ax[1,0])
sns.barplot(data=df,x='day_of_month',y='sales',ax=ax[1,1])
sns.barplot(data=df,x='week_of_year',y='sales',ax=ax[2,0])
sns.barplot(data=df,x='day_of_year',y='sales',ax=ax[2,1])

ax[0,0].set(xlabel='year',ylabel='sales',title='sales of year')
ax[0,1].set(xlabel='month',ylabel='sales',title='sales of month')
ax[1,0].set(xlabel='day_of_week',ylabel='sales',title='sales of dayofweek')
ax[1,1].set(xlabel='day_of_month',ylabel='sales',title='sales of dayofmonth')
ax[2,0].set(xlabel='week_of_year',ylabel='sales',title='sales of weekofyear')
ax[2,1].set(xlabel='day_of_year',ylabel='sales',title='sales of dayofyear')
# Out:
# [Text(0, 0.5, 'sales'),
#  Text(0.5, 0, 'day_of_year'),
#  Text(0.5, 1.0, 'sales of dayofyear')]

# %%
for train in [df]:
    train.loc[(train['week_of_year']<=9) | (train['week_of_year']>=49),'season'] = 1  # wintet
    train.loc[(train['week_of_year']>9) & (train['week_of_year']<=22),'season'] = 2   # spring
    train.loc[(train['week_of_year']>22) & (train['week_of_year']<=35),'season'] = 3  # summer
    train.loc[(train['week_of_year']>35) & (train['week_of_year']<=48),'season'] = 4  # fall

    train.loc[train['day_of_week']<=4,'weekday'] = 1  # weekday
    train.loc[train['day_of_week']>4,'weekday'] = 0   # weekend
df.head()
# Out:
#         date  store  item  sales  year  month  day_of_month  day_of_week  \
# 0 2013-01-01      1     1     13  2013      1             1            1
# 1 2013-01-02      1     1     11  2013      1             2            2
# 2 2013-01-03      1     1     14  2013      1             3            3
# 3 2013-01-04      1     1     13  2013      1             4            4
# 4 2013-01-05      1     1     10  2013      1             5            5
#
#    day_of_year  week_of_year  season  weekday
# 0            1             1     1.0      1.0
# 1            2             1     1.0      1.0
# 2            3             1     1.0      1.0
# 3            4             1     1.0      1.0
# 4            5             1     1.0      0.0

# %%
df.head()
# Out:
#         date  store  item  sales  year  month  day_of_month  day_of_week  \
# 0 2013-01-01      1     1     13  2013      1             1            1
# 1 2013-01-02      1     1     11  2013      1             2            2
# 2 2013-01-03      1     1     14  2013      1             3            3
# 3 2013-01-04      1     1     13  2013      1             4            4
# 4 2013-01-05      1     1     10  2013      1             5            5
#
#    day_of_year  week_of_year  season  weekday
# 0            1             1     1.0      1.0
# 1            2             1     1.0      1.0
# 2            3             1     1.0      1.0
# 3            4             1     1.0      1.0
# 4            5             1     1.0      0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 12 columns):
# date            913000 non-null datetime64[ns]
# store           913000 non-null int64
# item            913000 non-null int64
# sales           913000 non-null int64
# year            913000 non-null int64
# month           913000 non-null int64
# day_of_month    913000 non-null int64
# day_of_week     913000 non-null int64
# day_of_year     913000 non-null int64
# week_of_year    913000 non-null int64
# season          913000 non-null float64
# weekday         913000 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(9)
# memory usage: 83.6 MB

# %%
df['weekday'] = df['weekday'].astype(int)
df['season'] = df['season'].astype(int)

# %%
df.drop(columns=['date'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 11 columns):
# store           913000 non-null int64
# item            913000 non-null int64
# sales           913000 non-null int64
# year            913000 non-null int64
# month           913000 non-null int64
# day_of_month    913000 non-null int64
# day_of_week     913000 non-null int64
# day_of_year     913000 non-null int64
# week_of_year    913000 non-null int64
# season          913000 non-null int32
# weekday         913000 non-null int32
# dtypes: int32(2), int64(9)
# memory usage: 69.7 MB

# %%
df.columns
# Out:
# Index(['store', 'item', 'sales', 'year', 'month', 'day_of_month',
#        'day_of_week', 'day_of_year', 'week_of_year', 'season', 'weekday'],
#       dtype='object')

# %%
df.shape
# Out:
# (913000, 11)

# %%
x = df.iloc[:,[0,1,3,4,5,6,7,8,9,10]].values
y = df.iloc[:,2].values

# %%
# Train test Split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,
                                                random_state=0)

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.coef_
# Out:
# array([-7.55436795e-02, -1.11922660e-01,  4.18109752e+00,  1.67345994e+02,
#         5.49362600e+00,  3.10943157e+00, -5.49173900e+00, -1.35244109e-01,
#         5.77087333e+00, -4.64082837e-01])

# %%
lr_pred = lr.predict(x_test)
lr_pred
# Out:
# array([72.03765385, 47.89467599, 52.24884359, ..., 58.87126212,
#        30.40241028, 52.75099903])

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, lr_pred))
print('MSE:', metrics.mean_squared_error(y_test, lr_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, lr_pred)))
# Out:
# MAE: 21.338180899399664
# MSE: 701.9335840734831
# RMSE: 26.494029215532375

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(lr, x_train, y_train,
                         scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Scores: [26.56057201 26.61243798 26.44241348 26.59022269 26.61705999 26.55651265
#  26.43850907 26.47148537 26.59809238 26.52184412]
# Mean: 26.540914972528412
# Standard deviation: 0.06528206209210538

# %%
# Decision Tree
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
dt_pred = dt.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, dt_pred))
print('MSE:', metrics.mean_squared_error(y_test, dt_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, dt_pred)))
# Out:
# MAE: 8.37950930996714
# MSE: 119.25469879518073
# RMSE: 10.920379974853473

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(dt, x_train, y_train,
                         scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Scores: [10.93943832 10.90996577 10.94392024 10.93394018 10.9671693  10.88608881
#  10.94095808 10.94172089 10.9105206  10.86638489]
# Mean: 10.924010706525547
# Standard deviation: 0.02886965897320573

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf_pred = rf.predict(x_test)
rf_pred
# Out:
# array([71.4, 54.7, 41. , ..., 48. , 42.4, 25.9])

# %%
print('MAE:', metrics.mean_absolute_error(y_test, rf_pred))
print('MSE:', metrics.mean_squared_error(y_test, rf_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, rf_pred)))
# Out:
# MAE: 6.512180503833517
# MSE: 72.21624245345015
# RMSE: 8.498014029963127

# %%
test.head()
# Out:
#    id       date  store  item  year  month  day_of_month  day_of_week  \
# 0   0 2018-01-01      1     1  2018      1             1            0
# 1   1 2018-01-02      1     1  2018      1             2            1
# 2   2 2018-01-03      1     1  2018      1             3            2
# 3   3 2018-01-04      1     1  2018      1             4            3
# 4   4 2018-01-05      1     1  2018      1             5            4
#
#    day_of_year  week_of_year
# 0            1             1
# 1            2             1
# 2            3             1
# 3            4             1
# 4            5             1

# %%
test.drop(columns=['date'],axis=1,inplace=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 9 columns):
# id              45000 non-null int64
# store           45000 non-null int64
# item            45000 non-null int64
# year            45000 non-null int64
# month           45000 non-null int64
# day_of_month    45000 non-null int64
# day_of_week     45000 non-null int64
# day_of_year     45000 non-null int64
# week_of_year    45000 non-null int64
# dtypes: int64(9)
# memory usage: 3.1 MB

# %%
predictions = rf_pred.tolist()
predictions
# Out:
# [71.4,
#  54.7,
#  41.0,
#  77.7,
#  37.4,
#  50.1,
#  33.9,
#  21.0,
#  78.1,
#  86.6,
#  23.6,
#  63.4,
#  45.5,
#  34.0,
#  59.4,
#  109.1,
#  80.1,
#  21.5,
#  25.8,
#  82.6,
#  43.2,
#  98.9,
#  78.2,
#  81.9,
#  26.5,
#  49.9,
#  50.1,
#  63.3,
#  24.1,
#  64.8,
#  16.9,
#  102.4,
#  44.0,
#  31.4,
#  34.7,
#  59.2,
#  51.4,
#  63.6,
#  26.9,
#  28.2,
#  43.7,
#  28.7,
#  60.4,
#  35.8,
#  60.1,
#  31.7,
#  76.2,
#  32.1,
#  75.0,
#  32.6,
#  39.3,
#  35.3,
#  31.0,
#  18.2,
#  89.1,
#  31.8,
#  68.9,
#  52.3,
#  43.7,
#  25.0,
#  41.7,
#  26.1,
#  63.6,
#  62.5,
#  85.8,
#  19.7,
#  25.5,
#  30.4,
#  65.0,
#  36.1,
#  35.1,
#  41.1,
#  53.7,
#  53.1,
#  54.5,
#  52.9,
#  33.1,
#  32.7,
#  85.0,
#  25.6,
#  60.5,
#  73.8,
#  38.1,
#  34.9,
#  11.5,
#  42.0,
#  30.8,
#  43.3,
#  40.3,
#  87.9,
#  51.7,
#  45.0,
#  112.6,
#  34.0,
#  40.0,
#  83.1,
#  64.9,
#  26.5,
#  87.9,
#  74.9,
#  22.8,
#  40.7,
#  21.2,
#  30.0,
#  33.6,
#  21.7,
#  19.7,
#  50.7,
#  48.4,
#  20.5,
#  61.9,
#  35.0,
#  48.8,
#  45.7,
#  123.9,
#  29.4,
#  97.0,
#  73.3,
#  22.2,
#  73.3,
#  50.4,
#  102.9,
#  108.1,
#  22.6,
#  74.0,
#  66.0,
#  20.2,
#  20.5,
#  54.2,
#  67.8,
#  58.5,
#  55.5,
#  21.1,
#  49.0,
#  18.4,
#  46.9,
#  41.6,
#  40.2,
#  72.2,
#  128.7,
#  56.6,
#  44.1,
#  25.2,
#  46.7,
#  19.3,
#  36.1,
#  20.0,
#  55.0,
#  73.4,
#  73.1,
#  82.2,
#  81.1,
#  61.8,
#  22.8,
#  62.2,
#  84.8,
#  21.6,
#  33.8,
#  104.9,
#  42.7,
#  17.4,
#  21.6,
#  37.1,
#  62.6,
#  140.1,
#  25.8,
#  31.8,
#  25.2,
#  95.0,
#  39.8,
#  45.5,
#  98.2,
#  100.5,
#  70.9,
#  99.4,
#  55.9,
#  22.0,
#  26.8,
#  60.2,
#  40.4,
#  49.2,
#  48.8,
#  74.1,
#  16.2,
#  64.9,
#  72.1,
#  71.1,
#  68.6,
#  79.7,
#  49.4,
#  113.9,
#  20.6,
#  78.7,
#  21.0,
#  26.1,
#  44.9,
#  23.6,
#  51.4,
#  32.6,
#  26.9,
#  38.7,
#  74.4,
#  59.9,
#  41.3,
#  78.7,
#  66.7,
#  11.9,
#  15.4,
#  25.5,
#  62.1,
#  51.5,
#  43.9,
#  20.6,
#  59.0,
#  22.6,
#  62.9,
#  33.3,
#  9.1,
#  82.4,
#  78.3,
#  16.3,
#  28.5,
#  60.1,
#  98.3,
#  23.2,
#  17.9,
#  88.4,
#  111.5,
#  18.8,
#  55.3,
#  81.1,
#  20.4,
#  36.2,
#  37.6,
#  32.6,
#  61.0,
#  85.7,
#  69.2,
#  25.0,
#  64.9,
#  30.8,
#  24.8,
#  76.4,
#  54.3,
#  70.7,
#  104.2,
#  112.3,
#  17.6,
#  34.2,
#  29.3,
#  21.9,
#  21.1,
#  50.2,
#  20.2,
#  88.6,
#  59.1,
#  100.1,
#  90.6,
#  17.9,
#  36.4,
#  58.6,
#  16.5,
#  57.2,
#  87.6,
#  70.2,
#  34.9,
#  81.5,
#  29.0,
#  45.4,
#  101.8,
#  33.6,
#  35.3,
#  20.4,
#  48.0,
#  55.8,
#  63.4,
#  58.8,
#  34.0,
#  59.1,
#  63.5,
#  45.3,
#  12.1,
#  36.5,
#  41.7,
#  41.4,
#  8.7,
#  32.5,
#  50.6,
#  35.8,
#  23.4,
#  54.9,
#  72.7,
#  33.5,
#  13.8,
#  77.1,
#  14.9,
#  35.5,
#  38.2,
#  67.1,
#  38.6,
#  65.2,
#  34.6,
#  129.9,
#  20.5,
#  60.1,
#  66.3,
#  68.4,
#  41.8,
#  89.2,
#  63.7,
#  15.1,
#  27.3,
#  35.9,
#  32.4,
#  46.0,
#  35.0,
#  39.6,
#  106.9,
#  97.7,
#  20.3,
#  19.8,
#  78.5,
#  54.2,
#  24.5,
#  15.1,
#  28.8,
#  20.4,
#  98.8,
#  79.0,
#  55.3,
#  76.8,
#  41.2,
#  138.4,
#  58.2,
#  60.6,
#  44.6,
#  29.9,
#  101.4,
#  51.6,
#  113.5,
#  126.7,
#  35.0,
#  39.6,
#  28.4,
#  12.0,
#  4.9,
#  56.0,
#  27.6,
#  26.1,
#  94.1,
#  21.8,
#  31.1,
#  53.5,
#  144.1,
#  19.5,
#  15.8,
#  21.0,
#  53.6,
#  61.5,
#  76.4,
#  82.1,
#  61.3,
#  37.2,
#  53.3,
#  14.9,
#  46.6,
#  33.4,
#  52.5,
#  124.7,
#  28.8,
#  20.3,
#  51.3,
#  67.2,
#  48.4,
#  75.3,
#  77.1,
#  89.6,
#  19.5,
#  40.5,
#  15.8,
#  73.4,
#  77.9,
#  40.6,
#  162.7,
#  24.1,
#  104.8,
#  74.9,
#  27.7,
#  58.9,
#  66.0,
#  30.3,
#  45.5,
#  25.4,
#  24.7,
#  34.0,
#  43.0,
#  55.0,
#  77.7,
#  33.5,
#  22.6,
#  40.2,
#  64.3,
#  85.5,
#  36.9,
#  103.5,
#  65.0,
#  45.2,
#  52.8,
#  69.7,
#  69.1,
#  106.2,
#  17.9,
#  43.9,
#  94.0,
#  10.2,
#  74.9,
#  25.8,
#  65.7,
#  41.2,
#  31.1,
#  88.1,
#  37.8,
#  34.3,
#  65.6,
#  32.0,
#  107.6,
#  78.3,
#  11.1,
#  27.5,
#  50.8,
#  64.4,
#  89.2,
#  32.2,
#  69.1,
#  44.2,
#  91.1,
#  39.9,
#  66.6,
#  10.2,
#  47.8,
#  42.8,
#  47.2,
#  58.4,
#  92.4,
#  85.4,
#  24.7,
#  51.0,
#  32.4,
#  80.1,
#  67.4,
#  26.6,
#  9.9,
#  65.6,
#  99.6,
#  44.6,
#  9.7,
#  61.2,
#  150.0,
#  38.0,
#  43.0,
#  113.5,
#  66.3,
#  99.8,
#  32.6,
#  57.2,
#  29.5,
#  116.8,
#  16.5,
#  109.2,
#  20.6,
#  41.6,
#  52.7,
#  39.4,
#  104.8,
#  42.6,
#  92.5,
#  92.8,
#  91.1,
#  43.8,
#  51.0,
#  75.5,
#  56.3,
#  20.7,
#  16.5,
#  21.4,
#  54.1,
#  45.9,
#  71.1,
#  85.9,
#  63.4,
#  35.6,
#  103.0,
#  48.0,
#  34.5,
#  21.8,
#  52.2,
#  14.3,
#  36.7,
#  26.5,
#  33.8,
#  34.8,
#  86.0,
#  73.8,
#  92.9,
#  24.0,
#  125.9,
#  69.0,
#  30.4,
#  54.5,
#  45.7,
#  83.7,
#  28.7,
#  73.8,
#  108.3,
#  50.1,
#  69.2,
#  21.0,
#  59.3,
#  114.9,
#  15.9,
#  67.6,
#  47.1,
#  24.6,
#  38.1,
#  108.6,
#  16.1,
#  62.6,
#  36.1,
#  34.7,
#  58.0,
#  27.4,
#  16.6,
#  41.2,
#  89.4,
#  57.1,
#  49.3,
#  83.5,
#  51.4,
#  19.9,
#  116.7,
#  116.1,
#  134.5,
#  73.1,
#  73.2,
#  45.4,
#  47.4,
#  37.4,
#  41.1,
#  72.5,
#  90.4,
#  14.7,
#  45.1,
#  31.0,
#  12.8,
#  33.7,
#  86.8,
#  12.3,
#  70.3,
#  62.9,
#  18.2,
#  20.6,
#  14.5,
#  91.7,
#  88.6,
#  60.8,
#  87.2,
#  80.8,
#  55.2,
#  38.4,
#  16.7,
#  54.5,
#  32.5,
#  43.4,
#  86.5,
#  62.3,
#  26.3,
#  90.9,
#  39.9,
#  41.5,
#  43.2,
#  76.2,
#  30.8,
#  20.6,
#  18.3,
#  84.9,
#  90.8,
#  56.0,
#  29.7,
#  20.0,
#  22.5,
#  20.2,
#  40.7,
#  28.0,
#  100.7,
#  29.4,
#  95.0,
#  35.7,
#  94.9,
#  66.3,
#  32.2,
#  60.1,
#  46.2,
#  120.6,
#  112.8,
#  65.5,
#  22.5,
#  27.3,
#  85.3,
#  67.8,
#  41.7,
#  74.9,
#  125.1,
#  42.7,
#  43.3,
#  76.0,
#  44.3,
#  22.7,
#  78.6,
#  53.6,
#  34.6,
#  71.6,
#  50.6,
#  56.0,
#  83.2,
#  55.1,
#  55.0,
#  33.7,
#  37.8,
#  28.4,
#  30.5,
#  57.6,
#  14.7,
#  60.1,
#  35.5,
#  32.0,
#  59.9,
#  50.0,
#  47.7,
#  72.9,
#  40.9,
#  88.7,
#  55.6,
#  77.5,
#  17.6,
#  22.2,
#  100.2,
#  81.2,
#  21.4,
#  34.5,
#  27.7,
#  32.1,
#  38.1,
#  17.9,
#  21.9,
#  53.1,
#  72.2,
#  60.5,
#  63.5,
#  42.4,
#  24.4,
#  38.0,
#  28.4,
#  30.6,
#  22.2,
#  36.7,
#  97.6,
#  58.1,
#  60.1,
#  54.5,
#  45.3,
#  35.1,
#  66.0,
#  44.1,
#  107.6,
#  25.8,
#  51.6,
#  123.9,
#  48.2,
#  63.6,
#  91.3,
#  44.5,
#  33.3,
#  39.6,
#  31.9,
#  46.2,
#  35.3,
#  79.1,
#  85.1,
#  52.9,
#  25.6,
#  49.5,
#  30.1,
#  39.3,
#  43.4,
#  92.8,
#  16.6,
#  66.5,
#  9.7,
#  33.1,
#  30.7,
#  22.1,
#  30.0,
#  25.6,
#  27.4,
#  37.0,
#  24.2,
#  106.8,
#  28.1,
#  49.4,
#  110.7,
#  67.5,
#  38.6,
#  64.4,
#  111.2,
#  123.1,
#  103.9,
#  113.1,
#  55.6,
#  28.1,
#  34.5,
#  63.0,
#  33.0,
#  18.5,
#  16.0,
#  77.2,
#  21.2,
#  25.0,
#  28.2,
#  82.5,
#  44.6,
#  23.0,
#  42.8,
#  48.8,
#  52.4,
#  27.4,
#  77.5,
#  137.8,
#  45.2,
#  44.6,
#  69.5,
#  28.8,
#  21.9,
#  38.6,
#  25.7,
#  42.1,
#  78.4,
#  39.3,
#  48.7,
#  107.0,
#  31.4,
#  42.0,
#  25.4,
#  31.7,
#  83.1,
#  41.6,
#  72.2,
#  47.4,
#  58.7,
#  43.0,
#  32.8,
#  80.6,
#  59.2,
#  41.1,
#  132.8,
#  34.3,
#  96.6,
#  35.2,
#  18.3,
#  36.4,
#  70.9,
#  121.5,
#  56.3,
#  59.6,
#  26.7,
#  41.8,
#  30.4,
#  123.1,
#  63.6,
#  47.3,
#  12.1,
#  26.3,
#  94.0,
#  76.2,
#  51.1,
#  99.7,
#  54.8,
#  28.2,
#  30.8,
#  24.8,
#  68.2,
#  15.6,
#  87.7,
#  27.1,
#  78.8,
#  53.3,
#  72.9,
#  61.9,
#  10.0,
#  80.7,
#  33.6,
#  12.0,
#  86.2,
#  42.5,
#  32.1,
#  30.3,
#  65.5,
#  23.5,
#  72.8,
#  50.4,
#  49.5,
#  24.4,
#  34.3,
#  92.5,
#  79.5,
#  30.4,
#  36.6,
#  67.0,
#  82.0,
#  63.2,
#  58.7,
#  59.6,
#  63.9,
#  79.0,
#  22.9,
#  84.6,
#  21.7,
#  82.2,
#  66.8,
#  46.2,
#  91.6,
#  93.3,
#  36.2,
#  54.5,
#  93.0,
#  21.7,
#  20.9,
#  36.8,
#  17.8,
#  28.7,
#  28.2,
#  26.7,
#  63.9,
#  54.5,
#  32.2,
#  50.4,
#  62.0,
#  46.4,
#  51.2,
#  58.1,
#  75.9,
#  28.2,
#  35.4,
#  71.8,
#  43.6,
#  95.6,
#  24.7,
#  31.1,
#  56.7,
#  31.6,
#  33.6,
#  62.9,
#  25.3,
#  52.4,
#  53.0,
#  27.8,
#  72.9,
#  25.5,
#  34.6,
#  51.2,
#  44.3,
#  16.0,
#  24.2,
#  129.8,
#  16.8,
#  34.6,
#  91.7,
#  63.8,
#  31.7,
#  14.0,
#  27.9,
#  21.6,
#  16.2,
#  36.9,
#  62.2,
#  24.9,
#  119.8,
#  84.5,
#  12.2,
#  39.9,
#  89.9,
#  38.6,
#  25.8,
#  55.4,
#  63.8,
#  86.4,
#  100.2,
#  43.0,
#  60.5,
#  14.7,
#  42.2,
#  119.5,
#  80.3,
#  28.3,
#  143.1,
#  77.0,
#  74.3,
#  77.7,
#  9.9,
#  53.2,
#  48.8,
#  38.4,
#  15.2,
#  49.6,
#  50.4,
#  34.9,
#  27.0,
#  107.6,
#  75.1,
#  33.7,
#  59.5,
#  98.7,
#  74.1,
#  60.9,
#  30.7,
#  53.4,
#  80.7,
#  27.4,
#  20.2,
#  34.4,
#  23.5,
#  76.2,
#  99.0,
#  30.6,
#  47.3,
#  121.5,
#  115.2,
#  56.8,
#  69.1,
#  101.7,
#  59.4,
#  21.0,
#  89.5,
#  75.2,
#  42.7,
#  23.4,
#  54.3,
#  30.3,
#  61.0,
#  53.9,
#  50.0,
#  57.1,
#  26.0,
#  32.1,
#  68.3,
#  72.3,
#  15.4,
#  90.7,
#  35.2,
#  60.0,
#  22.5,
#  19.4,
#  8.5,
#  77.4,
#  36.7,
#  34.5,
#  17.4,
#  65.9,
#  26.9,
#  30.4,
#  76.4,
#  77.5,
#  77.5,
#  41.8,
#  74.1,
#  38.2,
#  73.2,
#  51.0,
#  85.8,
#  50.1,
#  36.1,
#  23.8,
#  91.1,
#  60.1,
#  53.3,
#  53.3,
#  26.6,
#  61.9,
#  63.6,
#  90.8,
#  24.7,
#  110.7,
#  57.4,
#  70.9,
#  61.9,
#  49.3,
#  60.1,
#  46.8,
#  67.0,
#  65.1,
#  75.8,
#  ...]

# %%
up_pred = np.array(predictions)

# %%
up_pred
# Out:
# array([71.4, 54.7, 41. , ..., 48. , 42.4, 25.9])
